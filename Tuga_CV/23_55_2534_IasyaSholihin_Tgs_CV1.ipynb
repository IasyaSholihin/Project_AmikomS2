# %% [markdown]
# <a href="https://colab.research.google.com/github/IasyaSholihin/Project_AmikomS2/blob/main/Tuga_CV/23_55_2534_IasyaSholihin_Tgs_CV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
from PIL import ImageEnhance
import cv2
import numpy as np
from matplotlib import pyplot as plt

from google.colab.patches import cv2_imshow

# Opens the image file
image = '/content/drive/MyDrive/Image_proc/saya1.jpg'
image = Image.open(image)
# shows image in image viewer
#img = plt. imread('image.png')
plt.imshow(image)
#image.show()


# Enhance Brightness

# %%
curr_bri = ImageEnhance.Brightness(image) #Augmentasi Kecerahan
new_bri = 0.5

# Brightness enhanced by a factor of 2.5
img_brightened = curr_bri.enhance(new_bri)

# shows updated image in image viewer
plt.imshow(img_brightened)

# %%
import cv2
from google.colab.patches import cv2_imshow  # Untuk Google Colab
import matplotlib.pyplot as plt
image = '/content/drive/MyDrive/Image_proc/saya1.jpg'
# Load image
image = cv2.imread(image)

# Periksa apakah gambar berhasil dimuat
if image is not None:
    # Tampilkan gambar
    plt.imshow(image)
    plt.axis('off')
    plt.show()

    # Peroleh dimensi gambar
    rows, cols, ch = image.shape
    print("Dimensi gambar:", rows, "x", cols, "dengan", ch, "channel")
else:
    print("Gagal memuat gambar.")
# Out:
# Dimensi gambar: 500 x 333 dengan 3 channel

# %%
img_rot = cv2.rotate(image, cv2.ROTATE_180)
cv2_imshow(img_rot)
img_rot.shape
# Out:
# <PIL.Image.Image image mode=RGB size=333x500>
# (500, 333, 3)

# %%
# Baca gambar segmentasi warna untuk mengekstraksi fitur-fitur
image_path = '/content/drive/MyDrive/Image_proc/saya1.jpg'
image = cv2.imread(image_path)

# Konversi gambar ke ruang warna HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Tentukan batas-batas untuk rentang warna kucing (misalnya, warna coklat)
lower_bound = np.array([0, 50, 50])  # Rentang warna bawah untuk coklat dalam HSV
upper_bound = np.array([30, 255, 255])  # Rentang warna atas untuk coklat dalam HSV

# Lakukan segmentasi warna
mask = cv2.inRange(hsv_image, lower_bound, upper_bound)

# Aplikasikan mask pada gambar asli untuk mendapatkan hasil segmentasi
segmented_image = cv2.bitwise_and(image, image, mask=mask)

# Tampilkan gambar asli dan hasil segmentasi
cv2_imshow(image)
cv2_imshow(segmented_image)
# Out:
# <PIL.Image.Image image mode=RGB size=333x500>
# <PIL.Image.Image image mode=RGB size=333x500>

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# Load images
img1 = cv.imread('/content/drive/MyDrive/Image_proc/saya1.jpg', cv.IMREAD_GRAYSCALE)
img2 = cv.imread('/content/drive/MyDrive/Image_proc/saya2.jpg', cv.IMREAD_GRAYSCALE)

# Initialize ORB detector
orb = cv.ORB_create()

# Find keypoints and descriptors
kp1, des1 = orb.detectAndCompute(img1, None)
kp2, des2 = orb.detectAndCompute(img2, None)

# Create brute-force matcher
bf = cv.BFMatcher(cv.NORM_HAMMING, crossCheck=True)

# Match descriptors
matches = bf.match(des1, des2)

# Sort matches based on distance
matches = sorted(matches, key=lambda x: x.distance)

# Draw first 10 matches
img3 = cv.drawMatches(img1, kp1, img2, kp2, matches[:90], None, flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# Display the matches
plt.imshow(img3), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7efeeb486ce0>, None)

# %%
# Baca gambar Deteksi tepi menggunakan metode Canny ( edge detection )
image_path = '/content/drive/MyDrive/Image_proc/saya1.jpg'
image = cv2.imread(image_path)

# Ubah gambar menjadi citra grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Deteksi tepi menggunakan metode Canny
edges = cv2.Canny(gray_image, 100, 90)  # Anda dapat menyesuaikan nilai ambang sesuai kebutuhan

# Tampilkan gambar asli
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

# Tampilkan hasil deteksi tepi
plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection (Canny)')
plt.axis('off')

plt.show()

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
